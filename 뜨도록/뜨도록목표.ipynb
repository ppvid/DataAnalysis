# %% [markdown]
# - 고객 유형 4가지
#     - 유형별 고객 구분 후 유료 전환을 클릭하는 사용자 추적
#     - ui 사용자별 언어 유형 구분 후 어떤 템플릿을 선호하는 지 추적(후순위, 현재는 템플릿 2개보유(탑다운 바텀업))
#     - 구매버튼 전환률
#         - 실제 결제 완료 됐을 때 연동하는 거, 클릭은 햇는데 결제 완료가 안됐을 때 이탈이 어디서 됐는지
# - 어떤 링크 타고 들어왔는지 추적하기(마케팅적 요소)
#     - 유입 채널별로 회원가입을 하는 비율 확인
#
# - UI 확인
#     - 처음 메인(랜딩)페이지에서 클릭하는 버튼이 뭔지 확인(목적성 확인)
#
# - 메인 페이지 고민..
#     - a/b테스트 했을 때 랜딩 페이지에 있는 설명들을 보고 넘어가는지 아닌지 확인하는 용도로 머무는 시간 보는 등으로 확인..
#     - 의미있는 메인 페이지를 만들고 싶다.
